# %% [markdown]
# # Aula 07 - O processo de análise de dados

# %% [markdown]
# ## 07.01 - Visão geral do processo de análise de dados
#
# ### Etapa 1: Fazer perguntas (Question)
# Ou você recebe os dados e faz perguntas baseadas neles ou faz as perguntas primeiro e, depois, reúne os dados com base nelas. Em ambos os casos, ótimas perguntas ajudam você a focar nas partes relevantes de seus dados e direcionar sua análise para insights significativos.
#
# ### Etapa 2: Limpar os dados (Wrangle)
# Você obtém os dados de que precisa de uma forma que consegue trabalhar em três etapas:
# - reunir (gather);
# - avaliar (asses); e
# - limpar (clean).
#
# Você reúne os dados de que precisa para responder às perguntas, avalia seus dados para identificar qualquer problema na qualidade ou estrutura deles e os limpa modificando, substituindo ou removendo dados para garantir que seu conjunto de dados seja da mais alta qualidade e o mais estruturado possível.
#
# ### Etapa 3: Realizar a análise exploratória de dados (do inglês, exploratory data analysis, ou EDA) (Explore)
# Você explora e, em seguida, aumenta seus dados para maximizar o potencial de suas análises, visualizações e modelos. Explorar envolve encontrar padrões em seus dados e visualizar relações entre eles e ter intuições sobre o assunto em que você está trabalhando. Após explorar, você pode fazer coisas como remover outliers e criar melhores recursos com seus dados, também conhecido como engenharia de recursos (feature engineering).
#
# ### Etapa 4: Tirar conclusões (ou até fazer previsões) (Draw conclusions)
# Esta etapa é geralmente abordada com machine learning ou estatísticas inferenciais que estão além do escopo desse curso, que focará em tirar conclusões com estatística descritiva.
#
#
# ### Etapa 5: Comunicar os resultados (Communicate)
# Você frequentemente precisa justificar e transmitir significado nos insights que encontrou. Ou, se seu objetivo final é construir um sistema, você normalmente precisa compartilhar o que construiu, explicar como chegou às decisões em relação ao design e reportar seu nível de desempenho. Existem muitas formas de comunicar seus resultados: relatórios, slides, postagens de blog, e-mails, apresentações ou até mesmo conversas. A visualização dos dados será sempre muito valiosa.

# %% [markdown]
# ## 07.02 - Visão geral sobre pacotes
#
# ### NumPy
# Da documentação oficial de Numpy (http://www.numpy.org/) , temos:
#
# > NumPy is the fundamental package for scientific computing with Python. It contains among other things:
# >
# > - a powerful N-dimensional array object
# > - sophisticated (broadcasting) functions
# > - tools for integrating C/C++ and Fortran code
# > - useful linear algebra, Fourier transform, and random number capabilities
# >
# > Besides its obvious scientific uses, NumPy can also be used as an efficient multi-dimensional container of generic data. Arbitrary data-types can be defined. This allows NumPy to seamlessly and speedily integrate with a wide variety of databases.
#
# ### Pandas
# Da documentação oficial de pandas (https://pandas.pydata.org/), temos:
#
# > Pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
#
# ### Matplotlib
# Da documentação oficial do Matplotlib (https://matplotlib.org/), temos:
#
# > Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shells, the Jupyter notebook, web application servers, and four graphical user interface toolkits.
# > Matplotlib tries to make easy things easy and hard things possible. You can generate plots, histograms, power spectra, bar charts, errorcharts, scatterplots, etc., with just a few lines of code. For examples, see the sample plots and thumbnail gallery.
# > For simple plotting the pyplot module provides a MATLAB-like interface, particularly when combined with IPython. For the power user, you have full control of line styles, font properties, axes properties, etc, via an object oriented interface or via a set of functions familiar to MATLAB users.
#
# ### Scikit Learn
# Da documentação oficial do Scikit Learn (http://scikit-learn.org/stable/), temos:
#
# >
# > - Simple and efficient tools for data mining and data analysis
# > - Accessible to everybody, and reusable in various contexts
# > - Built on NumPy, SciPy, and matplotlib
# > - Open source, commercially usable - BSD license
#
#
# ### IPython
# Da documentação oficial do IPython (https://ipython.org/), temos:
#
# > IPython provides a rich architecture for interactive computing with:
# > - A powerful interactive shell.
# > - A kernel for Jupyter.
# > - Support for interactive data visualization and use of GUI toolkits.
# > - Flexible, embeddable interpreters to load into your own projects.
# > - Easy to use, high performance tools for parallel computing.
#
#
# ### SciPy
# SciPy é um conjunto de pacotes para uso em engenharia, ciência e matemática. Contém o NumPy, Matplotlib, IPython, Simpy e pandas. (https://www.scipy.org/)

# %% [markdown]
# ## 07.03 - Lendo e gravando CSV

# %%
import pandas as pd

df = pd.read_csv("bases/alunos_notas.csv")
df.head()
# Out:
#    registro        Nome   Frq    HW  Teste1  Projeto1  Test2  Projeto2  Final
# 0     27604        José  0.96  0.97    87.0      98.0   92.0      93.0   95.0
# 1     30572   Alexandra  1.00  0.84    92.0      89.0   94.0      92.0   91.0
# 2     39203  Averistéia  0.84  0.74    68.0      70.0   84.0      90.0   82.0
# 3     28592   Kristiano  0.96  1.00    82.0      94.0   90.0      81.0   84.0
# 4     27492      Ricado  0.32  0.85    98.0     100.0   73.0      82.0   88.0

# %% [markdown]
# ### Teste com dataset pego em https://brasil.io/dataset/gastos-deputados/cota_parlamentar
# (Antes eu tinha usado uma base de portfolio de investimentos disponibilizada em http://archive.ics.uci.edu/ml/datasets/Stock+portfolio+performance. A base ainda está em "/bases/stock_portfolio_dataset_modified.csv".
#
# Eu modifiquei o arquivo original. Fiquei somente com a aba com todos os períodos, apaguei os dados de saída não normatizados, salvei em CSV e substitui a vírgula como símbolo decimal para ponto. Por fim, o arquivo está salvo no subdiretório bases com o nome "gastos-deputados-2017.csv".

# %% [markdown]
# #### Passo 1: acessando dados

# %%
dados_deputados = pd.read_csv("bases/gastos-deputados-2017.csv", header = 0)
dados_deputados.head()
# Out:
#    numano  nummes datemissao     txnomeparlamentar sgpartido sguf  \
# 0    2017      12        NaN     ABEL MESQUITA JR.       DEM   RR
# 1    2017      12        NaN     ABEL MESQUITA JR.       DEM   RR
# 2    2017      12        NaN  ADELMO CARNEIRO LEÃO        PT   MG
# 3    2017      12        NaN  ADELMO CARNEIRO LEÃO        PT   MG
# 4    2017      12        NaN       AFONSO FLORENCE        PT   BA
#
#   txtdescricao txtcnpjcpf      txtfornecedor  vlrdocumento  vlrglosa  \
# 0    TELEFONIA        NaN  CELULAR FUNCIONAL        490.80       0.0
# 1    TELEFONIA        NaN              RAMAL        141.51       0.0
# 2    TELEFONIA        NaN              RAMAL         71.39       0.0
# 3    TELEFONIA        NaN  CELULAR FUNCIONAL         39.56       0.0
# 4    TELEFONIA        NaN              RAMAL         25.63       0.0
#
#    vlrliquido
# 0      490.80
# 1      141.51
# 2       71.39
# 3       39.56
# 4       25.63

# %% [markdown]
# #### Passo 2: gravando em outro CSV

# %%
dados_deputados.to_csv("bases/dados_deputados_NOVO.csv")

# %% [markdown]
# ## 07.04 - Avaliando a intuição
# Uso do pandas para avaliação preliminar do dataset.

# %%
dados_deputados = pd.read_csv("bases/gastos-deputados-2017.csv", header = 0)

# isto retorna uma tupla com as mesmas dimensões do dataframe
dados_deputados.shape
# Out:
# (72101, 12)

# %%
# isto retorna os tipos de dados das colunas
dados_deputados.dtypes
# Out:
# numano                 int64
# nummes                 int64
# datemissao            object
# txnomeparlamentar     object
# sgpartido             object
# sguf                  object
# txtdescricao          object
# txtcnpjcpf            object
# txtfornecedor         object
# vlrdocumento         float64
# vlrglosa             float64
# vlrliquido           float64
# dtype: object

# %%
# isto exibe um resumo conciso do dataframe,
# incluindo o número de valores não-nulos em cada coluna
dados_deputados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72101 entries, 0 to 72100
# Data columns (total 12 columns):
# numano               72101 non-null int64
# nummes               72101 non-null int64
# datemissao           62564 non-null object
# txnomeparlamentar    72101 non-null object
# sgpartido            72101 non-null object
# sguf                 71906 non-null object
# txtdescricao         72101 non-null object
# txtcnpjcpf           58067 non-null object
# txtfornecedor        72101 non-null object
# vlrdocumento         72101 non-null float64
# vlrglosa             72101 non-null float64
# vlrliquido           72101 non-null float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 6.6+ MB

# %%
# isto retorna o número de valores únicos em cada coluna
dados_deputados.nunique()
# Out:
# numano                   1
# nummes                  12
# datemissao            4486
# txnomeparlamentar      561
# sgpartido               28
# sguf                    27
# txtdescricao            18
# txtcnpjcpf            9828
# txtfornecedor        12221
# vlrdocumento         29495
# vlrglosa              1507
# vlrliquido           29642
# dtype: int64

# %%
# isto retorna se a instância (ou registro) é duplicado
dados_deputados.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 72071     True
# 72072    False
# 72073    False
# 72074    False
# 72075    False
# 72076    False
# 72077    False
# 72078    False
# 72079    False
# 72080    False
# 72081    False
# 72082    False
# 72083    False
# 72084    False
# 72085    False
# 72086    False
# 72087    False
# 72088    False
# 72089    False
# 72090    False
# 72091    False
# 72092    False
# 72093    False
# 72094    False
# 72095    False
# 72096    False
# 72097    False
# 72098    False
# 72099    False
# 72100    False
# Length: 72101, dtype: bool

# %%
# isto retorna os campos duplicados
dados_deputados.drop_duplicates(inplace=True)

# %%
# isto retorna estatísticas descritivas úteis para cada coluna de dados
dados_deputados.describe()
# Out:
#         numano        nummes   vlrdocumento      vlrglosa     vlrliquido
# count  68680.0  68680.000000   68680.000000  68680.000000   68680.000000
# mean    2017.0     10.529499     777.492841      3.124888     750.415253
# std        0.0      2.032347    2682.635696     68.357313    2615.831586
# min     2017.0      1.000000   -3166.160000      0.000000   -3166.160000
# 25%     2017.0     10.000000      58.170000      0.000000      57.600000
# 50%     2017.0     11.000000     182.025000      0.000000     180.000000
# 75%     2017.0     12.000000     664.100000      0.000000     650.000000
# max     2017.0     12.000000  155000.000000   6000.000000  155000.000000

# %%
# isto retorna as primeiras linhas do nosso dataframe
# como padrão, retorna as primeiras cinco linhas
# embora você possa especificar quantas linhas você gostaria que fossem retornadas
dados_deputados.head(20)
# Out:
#     numano  nummes datemissao     txnomeparlamentar sgpartido sguf  \
# 0     2017      12        NaN     ABEL MESQUITA JR.       DEM   RR
# 1     2017      12        NaN     ABEL MESQUITA JR.       DEM   RR
# 2     2017      12        NaN  ADELMO CARNEIRO LEÃO        PT   MG
# 3     2017      12        NaN  ADELMO CARNEIRO LEÃO        PT   MG
# 4     2017      12        NaN       AFONSO FLORENCE        PT   BA
# 5     2017      12        NaN             ALAN RICK       DEM   AC
# 6     2017      12        NaN         ALEX CANZIANI       PTB   PR
# 7     2017      12        NaN          ANDRÉ AMARAL      PROS   PB
# 8     2017      12        NaN      ANDRÉ FIGUEIREDO       PDT   CE
# 9     2017      12        NaN         ALBERTO FILHO        PP   MA
# 10    2017      12        NaN         ANTONIO BRITO       PSD   BA
# 11    2017      12        NaN        ADAIL CARNEIRO      PODE   CE
# 12    2017      12        NaN  ADALBERTO CAVALCANTI    AVANTE   PE
# 13    2017      12        NaN  ADALBERTO CAVALCANTI    AVANTE   PE
# 14    2017      12        NaN       ADELSON BARRETO        PR   SE
# 15    2017      12        NaN         ADEMIR CAMILO       MDB   MG
# 16    2017      12        NaN   ARNALDO FARIA DE SÁ        PP   SP
# 17    2017      12        NaN       ALEXANDRE LEITE       DEM   SP
# 18    2017      12        NaN        AELTON FREITAS        PR   MG
# 19    2017      12        NaN       AFONSO FLORENCE        PT   BA
#
#    txtdescricao txtcnpjcpf      txtfornecedor  vlrdocumento  vlrglosa  \
# 0     TELEFONIA        NaN  CELULAR FUNCIONAL        490.80       0.0
# 1     TELEFONIA        NaN              RAMAL        141.51       0.0
# 2     TELEFONIA        NaN              RAMAL         71.39       0.0
# 3     TELEFONIA        NaN  CELULAR FUNCIONAL         39.56       0.0
# 4     TELEFONIA        NaN              RAMAL         25.63       0.0
# 5     TELEFONIA        NaN              RAMAL        105.11       0.0
# 6     TELEFONIA        NaN              RAMAL        235.07       0.0
# 7     TELEFONIA        NaN              RAMAL         85.06       0.0
# 8     TELEFONIA        NaN              RAMAL         83.04       0.0
# 9     TELEFONIA        NaN              RAMAL         89.84       0.0
# 10    TELEFONIA        NaN              RAMAL        119.15       0.0
# 11    TELEFONIA        NaN              RAMAL         36.06       0.0
# 12    TELEFONIA        NaN              RAMAL        194.88       0.0
# 13    TELEFONIA        NaN  CELULAR FUNCIONAL        799.50       0.0
# 14    TELEFONIA        NaN              RAMAL        134.90       0.0
# 15    TELEFONIA        NaN              RAMAL        107.70       0.0
# 16    TELEFONIA        NaN              RAMAL        291.59       0.0
# 17    TELEFONIA        NaN              RAMAL        149.42       0.0
# 18    TELEFONIA        NaN              RAMAL        174.43       0.0
# 19    TELEFONIA        NaN  CELULAR FUNCIONAL        987.86       0.0
#
#     vlrliquido
# 0       490.80
# 1       141.51
# 2        71.39
# 3        39.56
# 4        25.63
# 5       105.11
# 6       235.07
# 7        85.06
# 8        83.04
# 9        89.84
# 10      119.15
# 11       36.06
# 12      194.88
# 13      799.50
# 14      134.90
# 15      107.70
# 16      291.59
# 17      149.42
# 18      174.43
# 19      987.86

# %%
# isso também se aplicar ao comando `.tail()` que retorna as últimas linhas do dataframe
dados_deputados.tail(2)
# Out:
#        numano  nummes                 datemissao       txnomeparlamentar  \
# 72099    2017      10  2017-10-17 00:00:00+00:00  JOÃO FERNANDO COUTINHO
# 72100    2017      10  2017-10-17 00:00:00+00:00  JOÃO FERNANDO COUTINHO
#
#       sgpartido sguf                                txtdescricao  \
# 72099      PROS   PE               COMBUSTÍVEIS E LUBRIFICANTES.
# 72100      PROS   PE  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
#
#            txtcnpjcpf                     txtfornecedor  vlrdocumento  \
# 72099  10750039000180      POSTO DISBRAVE IMPERIAL LTDA         50.00
# 72100  04277081000394  RESTAURANTE DAS MINAS LTDA - EPP         65.49
#
#        vlrglosa  vlrliquido
# 72099       0.0       50.00
# 72100       0.0       65.49

# %%
# Exibir o índice e rótulo de cada coluna
for i, v in enumerate(dados_deputados.columns):
    print(i, v)
# Out:
# 0 numano
# 1 nummes
# 2 datemissao
# 3 txnomeparlamentar
# 4 sgpartido
# 5 sguf
# 6 txtdescricao
# 7 txtcnpjcpf
# 8 txtfornecedor
# 9 vlrdocumento
# 10 vlrglosa
# 11 vlrliquido

# %% [markdown]
# ## Prática de limpeza de dados (Cleaning)

# %%
# importe pandas e carregue dados sobre cancer
import pandas as pd

dados_prouni = pd.read_csv("bases/cursos-prouni.csv")

# verifique que colunas têm valores ausentes com info()
dados_prouni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41447 entries, 0 to 41446
# Data columns (total 16 columns):
# uf_busca                41447 non-null object
# cidade_busca            41447 non-null object
# universidade_nome       41447 non-null object
# campus_nome             41447 non-null object
# nome                    41447 non-null object
# grau                    41447 non-null object
# turno                   41447 non-null object
# mensalidade             41447 non-null float64
# bolsa_integral_cotas    32520 non-null float64
# bolsa_integral_ampla    25404 non-null float64
# bolsa_parcial_cotas     8828 non-null float64
# bolsa_parcial_ampla     13041 non-null float64
# nota_integral_ampla     32520 non-null float64
# nota_integral_cotas     16802 non-null float64
# nota_parcial_ampla      16350 non-null float64
# nota_parcial_cotas      5519 non-null float64
# dtypes: float64(9), object(7)
# memory usage: 5.1+ MB

# %%
# use médias para preencher valores ausentes
mean = dados_prouni["bolsa_integral_cotas"].mean()
dados_prouni["bolsa_integral_cotas"] = dados_prouni["bolsa_integral_cotas"].fillna(mean)

# confirme sua correção com info()
dados_prouni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41447 entries, 0 to 41446
# Data columns (total 16 columns):
# uf_busca                41447 non-null object
# cidade_busca            41447 non-null object
# universidade_nome       41447 non-null object
# campus_nome             41447 non-null object
# nome                    41447 non-null object
# grau                    41447 non-null object
# turno                   41447 non-null object
# mensalidade             41447 non-null float64
# bolsa_integral_cotas    41447 non-null float64
# bolsa_integral_ampla    25404 non-null float64
# bolsa_parcial_cotas     8828 non-null float64
# bolsa_parcial_ampla     13041 non-null float64
# nota_integral_ampla     32520 non-null float64
# nota_integral_cotas     16802 non-null float64
# nota_parcial_ampla      16350 non-null float64
# nota_parcial_cotas      5519 non-null float64
# dtypes: float64(9), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# ## Visualização de dados (data visualization)

# %%
import pandas as pd
% matplotlib inline

# o método hist() mostra histrogramas dos atributos que são numéricos.
# colocando o ";" no final, o método suprime a saída "não gráfica"
dados_prouni.hist(figsize = (20, 15));

# %%
#É possível separar um atributo só tbm.
dados_prouni["nota_integral_ampla"].hist(figsize = (6,4));

# %%
#Esse método agrega os valores únicos de uma coluna e os representa de maneira decrescente.
dados_prouni["universidade_nome"].value_counts()
# Out:
# Centro Universitário Internacional - Uninter - UNINTER                                          7335
# Universidade Paulista - UNIP                                                                    3800
# Universidade Pitágoras Unopar                                                                   2163
# Faculdade Educacional da Lapa - FAEL                                                            1198
# Centro Universitário de Maringá - Unicesumar - Unicesumar - UNICESUMAR                          1047
# Universidade Anhanguera - UNIDERP                                                               1044
# Universidade Cidade de São Paulo - UNICID                                                        977
# Centro Universitário Cenecista de Osório - Unicnec - UNICNEC                                     838
# Centro Universitário Leonardo da VInci - UNIASSELVI                                              820
# Centro Universitário Estácio de Ribeirão Preto - Estácio Ribeirão Pre - ESTÁCIO RIBEIRÃO PRE     654
# Centro Universitário Claretiano - Ceuclar - CEUCLAR                                              648
# Universidade Nove de Julho - UNINOVE                                                             588
# Universidade de Franca - UNIFRAN                                                                 487
# Universidade Cruzeiro do Sul - UNICSUL                                                           412
# Centro Universitário de Jaguariúna - Faj - FAJ                                                   381
# Centro Universitário da Grande Dourados - Unigran - UNIGRAN                                      368
# Universidade de Uberaba - UNIUBE                                                                 335
# Universidade Tiradentes - UNIT                                                                   191
# Centro Universitário Campos de Andrade - Uniandrade - UNIANDRADE                                 160
# Pontifícia Universidade Católica de Minas Gerais - PUC MINAS                                     150
# Universidade Anhembi Morumbi - UAM                                                               148
# Universidade Positivo - UP                                                                       132
# Universidade do Oeste de Santa Catarina - UNOESC                                                 126
# Universidade Salvador - UNIFACS                                                                  120
# Faculdade de Ensino Superior da Cidade de Feira de Santana - FAESF/UNEF                          119
# Faculdade das Américas - FAM                                                                     118
# Universidade do Ceuma - Uniceuma - UNICEUMA                                                      117
# Universidade do Vale do Rio dos Sinos - UNISINOS                                                 115
# Faculdade Regional da Bahia - FARB                                                               110
# Universidade Braz Cubas - UBC                                                                    108
#                                                                                                 ...
# Faculdade Unime de Ciências Jurídicas - FCJ                                                        1
# Instituto Superior de Educação Santa Rita de Cássia - ISESC                                        1
# Faculdade Universus Veritas de Belo Horizonte                                                      1
# Faculdade Evangélica do Paraná - FEPAR                                                             1
# Faculdade Maurício de Nassau de VItória - FMN VITÓRIA                                              1
# Faculdade de Educação de Assis - FAEDA                                                             1
# Faculdade Ágora - Fag - FAG                                                                        1
# Faculdade de São Roque - FAEV                                                                      1
# Faculdade Doctum de Carangola - DOCTUM                                                             1
# Faculdade de Administração de Cataguases - UNIPACAT                                                1
# Faculdade Uninassau Juazeiro do Norte                                                              1
# Faculdade VIdal de Limoeiro - FAVILI                                                               1
# Faculdade Maurício de Nassau de Sobral - FMN SOBRAL                                                1
# Faculdade Icg                                                                                      1
# Faculdades Integradas São Pedro - FAESA                                                            1
# Unama Faculdade da Amazônia de Macapá                                                              1
# Faculdade Dourado - FD                                                                             1
# Faculdade de Ciências Humanas,Exatas e da Saúde do Piauí - FAHESP                                  1
# Faculdade de Direito de VItória - FDV                                                              1
# Faculdade Cuiabá - FAUC                                                                            1
# Faculdade Anglo-Americano de João Pessoa - FAAJP                                                   1
# Faculdade São Bento da Bahia - FSBB                                                                1
# Escola Superior de Aviação Civil - ESAC                                                            1
# Faculdade Integrada de Cariacica - MULTIVIX CARIAC                                                 1
# Faculdade de Ciências Médicas de São José dos Campos                                               1
# Faculdade da Amazônia de Porto Velho                                                               1
# Cisne - Faculdade de Quixadá - CFQ                                                                 1
# Faculdade Waldir Filho                                                                             1
# Faculdade Horus Säo Miguel - FSJ                                                                   1
# Faculdade de Administração da Associação Brasiliense de Educação - FABE                            1
# Name: universidade_nome, Length: 1299, dtype: int64

# %%
# Ao método anterior é possível adicionar de plotar um gráfico de barras.
% matplotlib inline
dados_prouni["universidade_nome"].value_counts().head(30).plot(kind="bar", figsize = (12,4));
# Importante perceber que na instrução acima mesclei vários métodos. Outro ponto importantíssimo
# é que o resultado é dependente da posição do método na instrução. É uma obviedade, mas é bom salientar.

# %%
# Compare com a instrução acima. "Apenas" coloquei o método head() antes de value_caounts.
dados_prouni["universidade_nome"].head(30).value_counts().plot(kind="bar", figsize = (12,4));

# %%
# Gráfico de pizza
dados_prouni["turno"].value_counts().plot(kind="pie",figsize=(10,10));

# %%
pd.plotting.scatter_matrix(dados_prouni, figsize = (20,20));

# %%
dados_prouni.plot(x = "mensalidade", y = "nota_integral_ampla", kind = "scatter");

# %%
dados_prouni["nota_integral_ampla"].plot(kind = 'box');
